# %% [markdown]
# # Popular Data Science Questions
#
# Using [Data Science Stack Exchange](https://datascience.stackexchange.com/), the goal of this project is to determine the best content to create for a data science company based on interest by subject.
#
# # Stack Exchange
#
# ## What kind of questions are welcome on this site?
# On DSSE's help center's section on [questions](https://datascience.stackexchange.com/help/asking) , we can read that we should:
#
# * Avoid subjective questions.
# * Ask practical questions about Data Science — there are adequate sites for theoretical questions.
# * Ask specific questions.
# * Make questions relevant to others.
#
# All of these characteristics, if employed, should be helpful attributes to our goal.
#
# In the help center we also learned that there are other two sites that are relevant:
# * [Open Data](https://opendata.stackexchange.com/help/on-topic) (Dataset requests)
# * [Computational Science](https://scicomp.stackexchange.com/help/on-topic) (Software packages and algorithms in applied mathematics)

# %% [markdown]
# ## What, other than questions, does the site's home subdivide into?
#
# On the [home page](https://datascience.stackexchange.com) we can see that we have four sections:
# * [Questions](https://datascience.stackexchange.com/questions) — a list of all questions asked;
# * [Tags](https://datascience.stackexchange.com/tags) — keywords or labels that categorize questions;
# * [Users](https://datascience.stackexchange.com/users) — a list of users;
# * [Unanswered](https://datascience.stackexchange.com/unanswered) — a list of unanswered questions;
#
# ![Screen%20Shot%202020-09-06%20at%2012.44.49.png](attachment:Screen%20Shot%202020-09-06%20at%2012.44.49.png)
#
# The tagging system used by Stack Exchange looks just like what we need to solve this problem as it allow us to quantify how many questions are asked about each subject.
# Something else we can learn from exploring the help center, is that Stack Exchange's sites are heavily moderated by the community; this gives us some confidence in using the tagging system to derive conclusions.

# %% [markdown]
# ## What information is available in each post?
#
# Looking, just as an example, at this [question](https://datascience.stackexchange.com/questions/53858/formal-proof-of-vanilla-policy-gradient-convergence), some of the information we see is:
#
# * The posts's score;
# * The posts's title;
# * The posts's author;
# * The posts's body;
# * The last time the question as active;
# * How many times the question was viewed;
# * Related questions;
# * The question's tags;

# %% [markdown]
# ## Stack Exchange Data Explorer
#
# Stack Exchange provides a public data base for each of its websites. This [link](https://data.stackexchange.com/datascience/query/new) is used to query and explore Data Science Stack Exchange's database.
#
# More about Stack Exchange Data Explorer (SEDE) on its [help section](https://data.stackexchange.com/help) and on this [tutorial link](https://data.stackexchange.com/tutorial).
#
# In the image below we can see the names of each of the tables in the database. Clicking on the names will expand to show the columns of each table.
#
# ![image](https://dq-content.s3.amazonaws.com/469/dsde.png)
#
# Exploreing the Data Science Stack Exchange's data model and investigating the tables, the below have been identified as promising towards finding the most popular content:
#
# * Post
# * PostTags
# * Tags
# * Vote
#
# We will be focusing on the `Post` as it contains the relevant information we need for example, the **ViewCount**, **Score** and so on.

# %% [markdown]
# ## Getting the Data
#
# The posts table has a lot of columns. We'll be focusing our attention on those that seem relevant towards our goal:
#
# * `Id`: An identification number for the post.
# * `PostTypeId`: An identification number for the type of post.
#
# ![image](https://dq-content.s3.amazonaws.com/469/PostTypes.png)
#
# * `CreationDate`: The date and time of creation of the post.
# * `Score`: The post's score.
# * `ViewCount`: How many times the post was viewed.
# * `Tags`: What tags were used.
# * `AnswerCount`: How many answers the question got (only applicable to question posts).
# * `FavoriteCount`: How many times the question was favored (only applicable to question posts).
#
# Note that with the exception of the tags column, the last few columns contain information about how popular the post is — the kind of information we're after.
#
# There are eight different types of post. Before we try to figure out which of them are relevant to us, let's check how many of them there are:
#
# ![Screen%20Shot%202020-09-06%20at%2017.11.09.png](attachment:Screen%20Shot%202020-09-06%20at%2017.11.09.png)

# %% [markdown]
# ![Screen%20Shot%202020-09-07%20at%2017.47.53.png](attachment:Screen%20Shot%202020-09-07%20at%2017.47.53.png)
#
# We'll limit our analysis to the posts of 2019 and focus on the posts that are questions.

# %% [markdown]
# Running a query against the SEDE DSSE database that extracts the columns listed above for all the questions in 2019.
#
# ![Screen%20Shot%202020-09-07%20at%2017.53.29.png](attachment:Screen%20Shot%202020-09-07%20at%2017.53.29.png)

# %% [markdown]
# Here are the first few rows. We can see that favourite count has some missing values.
# ![Screen%20Shot%202020-09-07%20at%2017.54.25.png](attachment:Screen%20Shot%202020-09-07%20at%2017.54.25.png)

# %% [markdown]
# The result of the query was stored in a file called `2019_questions.csv`.

# %% [markdown]
# # Exploring the Data

# %%
import pandas as pd
original_questions = pd.read_csv('2019_questions.csv')
questions = original_questions.copy()
questions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7540 entries, 0 to 7539
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             7540 non-null   int64
#  1   PostTypeId     7540 non-null   int64
#  2   CreationDate   7540 non-null   object
#  3   Score          7540 non-null   int64
#  4   ViewCount      7540 non-null   int64
#  5   Tags           7540 non-null   object
#  6   AnswerCount    7540 non-null   int64
#  7   FavoriteCount  1525 non-null   float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 471.4+ KB

# %%
questions.head()
# Out:
#       Id  PostTypeId         CreationDate  Score  ViewCount  \
# 0  61536           1  2019-10-10 05:58:58      1        131
# 1  61540           1  2019-10-10 06:51:08      0         26
# 2  61544           1  2019-10-10 08:28:22      0         26
# 3  61546           1  2019-10-10 09:06:55      0        268
# 4  61547           1  2019-10-10 09:37:34      0         15
#
#                                                 Tags  AnswerCount  \
# 0  <machine-learning><neural-network><reinforceme...            1
# 1                     <machine-learning><classifier>            1
# 2                                      <dataset><ml>            1
# 3  <machine-learning><python><deep-learning><kera...            1
# 4                                         <r>            0
#
#    FavoriteCount
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
questions.isnull().sum()
# Out:
# Id                  0
# PostTypeId          0
# CreationDate        0
# Score               0
# ViewCount           0
# Tags                0
# AnswerCount         0
# FavoriteCount    6015
# dtype: int64

# %% [markdown]
# `FavoriteCount` has 6015 missing values. This probably means that this was not present in the user's favourite list and so we can replace it with **0**

# %%
questions['FavoriteCount'] = 0
questions['Tags'].apply(lambda value: type(value)).unique()
# Out:
# array([<class 'str'>], dtype=object)

# %% [markdown]
# All data in the `Tags` are strings.

# %% [markdown]
# # Cleaning the Data
#
# Let's change the type of the `CreationDate` to `datetime[ns]` and clean up the `Tags` column.

# %%
import datetime
questions['CreationDate'] = questions['CreationDate'].astype(('datetime64[ns]'))

# %%
questions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7540 entries, 0 to 7539
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             7540 non-null   int64
#  1   PostTypeId     7540 non-null   int64
#  2   CreationDate   7540 non-null   datetime64[ns]
#  3   Score          7540 non-null   int64
#  4   ViewCount      7540 non-null   int64
#  5   Tags           7540 non-null   object
#  6   AnswerCount    7540 non-null   int64
#  7   FavoriteCount  7540 non-null   int64
# dtypes: datetime64[ns](1), int64(6), object(1)
# memory usage: 471.4+ KB

# %%
questions['Tags'].head()
# Out:
# 0    <machine-learning><neural-network><reinforceme...
# 1                       <machine-learning><classifier>
# 2                                        <dataset><ml>
# 3    <machine-learning><python><deep-learning><kera...
# 4                                           <r>
# Name: Tags, dtype: object

# %%
#using a regex expression
questions['Tags'] = questions["Tags"].str.replace("^<|>$", "").str.split("><")

# %%
questions['Tags'].head(5)
# Out:
# 0    [machine-learning, neural-network, reinforceme...
# 1                       [machine-learning, classifier]
# 2                                        [dataset, ml]
# 3    [machine-learning, python, deep-learning, kera...
# 4                                           [r, image]
# Name: Tags, dtype: object

# %% [markdown]
# ## Most Used and Most Viewed
#
# We now focus on determining the most popular tags. We'll do so by considering two different popularity proxies: for each tag we'll count how many times the tag was used, and how many times a question with that tag was viewed.

# %%
questions['Tags'].sample(10)
# Out:
# 7186                         [classification, perceptron]
# 3422                       [python, software-development]
# 4315                                         [keras, mlp]
# 4230                                [neural-network, cnn]
# 913                            [python, jupyter, ipython]
# 7298    [machine-learning, gaussian, discriminant-anal...
# 1696           [scikit-learn, feature-selection, xgboost]
# 6967     [python, classification, svm, tfidf, classifier]
# 6707            [python, neural-network, keras, accuracy]
# 1322    [machine-learning, categorical-data, beginner,...
# Name: Tags, dtype: object

# %% [markdown]
# Let's count how many times the tag was used...

# %%
used_tags = {}
for tags in questions['Tags']:
    for tag in tags:
        if tag in used_tags:
            used_tags[tag] += 1
        else:
            used_tags[tag] = 1

# %%
used_tags
# Out:
# {'machine-learning': 2332,
#  'neural-network': 913,
#  'reinforcement-learning': 170,
#  'dqn': 30,
#  'classifier': 17,
#  'dataset': 284,
#  'ml': 6,
#  'python': 1580,
#  'deep-learning': 1003,
#  'keras': 796,
#  'convnet': 93,
#  'r': 227,
#  'image': 27,
#  'scikit-learn': 482,
#  'pandas': 333,
#  'linear-regression': 154,
#  'classification': 612,
#  'class-imbalance': 68,
#  'imbalanced-learn': 20,
#  'tensorflow': 480,
#  'data-science-model': 163,
#  'nlp': 434,
#  'named-entity-recognition': 32,
#  'spacy': 20,
#  'predictive-modeling': 230,
#  'lstm': 313,
#  'embeddings': 42,
#  'data-mining': 187,
#  'correlation': 74,
#  'association-rules': 12,
#  'pattern-recognition': 2,
#  'dataframe': 75,
#  'pca': 78,
#  'descriptive-statistics': 18,
#  'normalization': 67,
#  'ensemble-modeling': 26,
#  'activation-function': 38,
#  'gan': 69,
#  'generative-models': 36,
#  'mnist': 21,
#  'sampling': 29,
#  'time-series': 367,
#  'regression': 303,
#  'probability': 56,
#  'bayesian': 30,
#  'dirichlet': 4,
#  'object-detection': 78,
#  'object-recognition': 12,
#  'statistics': 199,
#  'cross-validation': 131,
#  'feature-selection': 185,
#  'word2vec': 68,
#  'word-embeddings': 104,
#  'gensim': 30,
#  'sequence-to-sequence': 26,
#  'churn': 14,
#  'cnn': 411,
#  'logistic-regression': 132,
#  'image-classification': 178,
#  'matplotlib': 70,
#  'openai-gym': 15,
#  'hyperparameter': 37,
#  'hyperparameter-tuning': 53,
#  'sas': 6,
#  'svm': 113,
#  'evaluation': 60,
#  'overfitting': 61,
#  'k-nn': 46,
#  'bayes-error': 1,
#  'pytorch': 135,
#  'meta-learning': 3,
#  'data-cleaning': 133,
#  'preprocessing': 107,
#  'missing-data': 32,
#  'data-analysis': 58,
#  'data-imputation': 12,
#  'pooling': 3,
#  'categorical-data': 72,
#  'encoding': 48,
#  'convolution': 81,
#  'cosine-distance': 19,
#  'rnn': 119,
#  'text': 36,
#  'binary': 23,
#  'model-selection': 47,
#  'topic-model': 25,
#  'lda': 23,
#  'sql': 23,
#  'seaborn': 34,
#  'random-forest': 142,
#  'matlab': 45,
#  'lda-classifier': 1,
#  'q-learning': 30,
#  'deep-network': 27,
#  'bigdata': 71,
#  'machine-learning-model': 195,
#  'data': 185,
#  'kaggle': 39,
#  'visualization': 115,
#  'ipython': 17,
#  '3d-reconstruction': 8,
#  'transfer-learning': 56,
#  'faster-rcnn': 24,
#  'difference': 4,
#  'grid-search': 31,
#  'clustering': 243,
#  'dimensionality-reduction': 61,
#  'optimization': 100,
#  'outlier': 48,
#  'recommender-system': 75,
#  'gradient-descent': 83,
#  'knime': 1,
#  'linear-algebra': 21,
#  'confusion-matrix': 25,
#  'multilabel-classification': 81,
#  'clusters': 9,
#  'estimators': 4,
#  'sentiment-analysis': 34,
#  'labels': 27,
#  'vgg16': 20,
#  'numpy': 106,
#  'apache-spark': 29,
#  'feature-engineering': 140,
#  'learning': 9,
#  'learning-to-rank': 6,
#  'dynamic-programming': 3,
#  'multiclass-classification': 115,
#  'naive-bayes-classifier': 36,
#  'image-preprocessing': 54,
#  'mlp': 31,
#  'perceptron': 24,
#  'machine-translation': 22,
#  'natural-language-process': 104,
#  'k-means': 78,
#  'accuracy': 80,
#  'markov-process': 12,
#  'anomaly-detection': 77,
#  'autoencoder': 83,
#  'pyspark': 33,
#  'distribution': 47,
#  'variance': 31,
#  'gaussian': 17,
#  'neural-style-transfer': 8,
#  'policy-gradients': 25,
#  'ai': 25,
#  'decision-trees': 130,
#  'boosting': 44,
#  'computer-vision': 104,
#  'self-driving': 2,
#  'stemming': 2,
#  'xgboost': 156,
#  'unbalanced-classes': 37,
#  'image-recognition': 68,
#  'ocr': 23,
#  'scoring': 9,
#  'gridsearchcv': 24,
#  'text-mining': 92,
#  'information-retrieval': 29,
#  'bias': 17,
#  'backpropagation': 53,
#  'chatbot': 9,
#  'usecase': 1,
#  'feature-scaling': 56,
#  'supervised-learning': 76,
#  'regex': 7,
#  'sparsity': 2,
#  'explainable-ai': 9,
#  'feature-extraction': 71,
#  'orange': 54,
#  'orange3': 16,
#  'csv': 22,
#  'julia': 2,
#  'data-augmentation': 21,
#  'text-generation': 15,
#  'text-filter': 1,
#  'training': 121,
#  'forecasting': 64,
#  'similar-documents': 15,
#  'vector-space-models': 4,
#  'regularization': 44,
#  'tsne': 13,
#  'loss-function': 145,
#  'aws': 12,
#  'opencv': 32,
#  'prediction': 107,
#  'feature-construction': 13,
#  'data-wrangling': 15,
#  'javascript': 8,
#  'geospatial': 23,
#  'plotting': 30,
#  'forecast': 24,
#  'graphical-model': 3,
#  'historgram': 6,
#  'social-network-analysis': 11,
#  'unsupervised-learning': 96,
#  'weka': 16,
#  'bert': 57,
#  'similarity': 59,
#  'language-model': 20,
#  'transformer': 41,
#  'recurrent-neural-net': 69,
#  'metadata': 2,
#  'tools': 6,
#  'yolo': 13,
#  'sensors': 2,
#  'smote': 25,
#  'beginner': 24,
#  'programming': 6,
#  'algorithms': 55,
#  'distance': 39,
#  'lightgbm': 23,
#  'performance': 25,
#  'features': 24,
#  'dropout': 13,
#  'tfidf': 28,
#  'batch-normalization': 25,
#  'databases': 24,
#  'project-planning': 6,
#  'audio-recognition': 23,
#  'research': 8,
#  'vae': 8,
#  'neural': 14,
#  'google': 16,
#  'excel': 24,
#  'kernel': 22,
#  'mathematics': 23,
#  'multi-output': 7,
#  'functional-api': 1,
#  'relational-dbms': 7,
#  'noise': 13,
#  'online-learning': 11,
#  'h2o': 3,
#  'graphs': 43,
#  'notation': 4,
#  'terminology': 16,
#  'nltk': 40,
#  'stanford-nlp': 9,
#  'indexing': 5,
#  'corpus': 1,
#  'wikipedia': 1,
#  'matrix': 21,
#  'twitter': 8,
#  'actor-critic': 19,
#  'keras-rl': 6,
#  'annotation': 10,
#  'fuzzy-logic': 10,
#  'fuzzy-classification': 3,
#  'ab-test': 5,
#  'weight-initialization': 7,
#  'jupyter': 37,
#  'pickle': 8,
#  'mean-shift': 2,
#  'siamese-networks': 4,
#  'semantic-similarity': 2,
#  'simulation': 7,
#  'data-formats': 9,
#  'mse': 7,
#  'genetic-algorithms': 13,
#  'community': 1,
#  'rbm': 2,
#  'error-handling': 15,
#  'monte-carlo': 11,
#  'collinearity': 6,
#  'anonymization': 3,
#  'scipy': 36,
#  'arima': 11,
#  'python-3.x': 13,
#  'statsmodels': 1,
#  'json': 7,
#  'lasso': 8,
#  'rstudio': 13,
#  'ggplot2': 3,
#  'software-development': 2,
#  'hardware': 11,
#  'metric': 53,
#  'web-scraping': 8,
#  'math': 33,
#  'matrix-factorisation': 15,
#  'methodology': 7,
#  'gpu': 40,
#  'softmax': 21,
#  'homework': 4,
#  'theory': 10,
#  'evolutionary-algorithms': 9,
#  'reference-request': 15,
#  'semi-supervised-learning': 13,
#  'scraping': 4,
#  'java': 8,
#  'sequence': 19,
#  'dummy-variables': 19,
#  'self-study': 8,
#  'code': 5,
#  'gaussian-process': 9,
#  'cost-function': 22,
#  'colab': 18,
#  'data-leakage': 8,
#  'sequential-pattern-mining': 12,
#  'mini-batch-gradient-descent': 9,
#  'sap': 1,
#  'attention-mechanism': 23,
#  'aggregation': 8,
#  'implementation': 20,
#  'privacy': 4,
#  'anaconda': 17,
#  'galago': 1,
#  'caffe': 3,
#  'learning-rate': 6,
#  'pipelines': 16,
#  'methods': 4,
#  'ranking': 15,
#  'score': 12,
#  'nosql': 3,
#  'reshape': 9,
#  'etl': 4,
#  'weighted-data': 11,
#  'google-prediction-api': 1,
#  'market-basket-analysis': 7,
#  'non-parametric': 4,
#  'bayesian-nonparametric': 2,
#  'survival-analysis': 8,
#  'discriminant-analysis': 5,
#  'time': 4,
#  'nlg': 8,
#  'powerbi': 6,
#  'management': 2,
#  'generalization': 10,
#  'word': 2,
#  'representation': 6,
#  'career': 8,
#  'data.table': 3,
#  'scala': 7,
#  'least-squares-svm': 1,
#  'markov': 3,
#  'windows': 3,
#  'multitask-learning': 5,
#  'inception': 7,
#  'probability-calibration': 11,
#  'finetuning': 6,
#  'automatic-summarization': 9,
#  'serialisation': 3,
#  'bayesian-networks': 11,
#  'rbf': 4,
#  'finance': 13,
#  'parameter-estimation': 4,
#  'ensemble': 5,
#  'numerical': 5,
#  'hinge-loss': 7,
#  'one-shot-learning': 2,
#  'octave': 2,
#  'search-engine': 3,
#  'question-answering': 4,
#  'huggingface': 1,
#  'ndcg': 5,
#  'discounted-reward': 5,
#  'parallel': 7,
#  'parsing': 3,
#  'tokenization': 5,
#  'derivation': 5,
#  'inceptionresnetv2': 5,
#  'markov-hidden-model': 7,
#  'bioinformatics': 4,
#  'search': 3,
#  'mcmc': 3,
#  'feature-reduction': 3,
#  'marketing': 3,
#  'distributed': 4,
#  'svr': 4,
#  'smotenc': 4,
#  'books': 6,
#  'predictor-importance': 10,
#  'feature-map': 2,
#  'dbscan': 16,
#  'expectation-maximization': 5,
#  'cloud-computing': 7,
#  'epochs': 11,
#  'software-recommendation': 3,
#  'deepmind': 6,
#  'vc-theory': 5,
#  'crawling': 3,
#  'movielens': 2,
#  'image-size': 4,
#  'infographics': 2,
#  'stata': 1,
#  'wolfram-language': 3,
#  'azure-ml': 10,
#  'convergence': 14,
#  'processing': 4,
#  'momentum': 1,
#  'stacked-lstm': 6,
#  'apache-hadoop': 8,
#  'scalability': 3,
#  'information-theory': 7,
#  'mutual-information': 4,
#  'doc2vec': 3,
#  'nvidia': 6,
#  'game': 4,
#  'state-of-the-art': 1,
#  'ann': 2,
#  'randomized-algorithms': 6,
#  'jaccard-coefficient': 3,
#  'rmse': 1,
#  'interpolation': 5,
#  'anova': 1,
#  'dplyr': 4,
#  'image-segmentation': 3,
#  'tableau': 7,
#  'heatmap': 8,
#  'genetic-programming': 2,
#  'parameter': 5,
#  'map-reduce': 3,
#  'ngrams': 4,
#  'education': 2,
#  'manhattan': 3,
#  'version-control': 1,
#  'pruning': 3,
#  'networkx': 2,
#  'probabilistic-programming': 7,
#  'alex-net': 3,
#  'pytorch-geometric': 2,
#  'allennlp': 2,
#  'interpretation': 3,
#  'pip': 4,
#  'pac-learning': 6,
#  'linux': 4,
#  'objective-function': 2,
#  'definitions': 4,
#  'ridge-regression': 6,
#  'fastai': 3,
#  'cloud': 4,
#  'categorical-encoding': 3,
#  'speech-to-text': 7,
#  'one-hot-encoding': 4,
#  'pearsons-correlation-coefficient': 2,
#  'spearmans-rank-correlation': 1,
#  'kendalls-tau-coefficient': 1,
#  'groupby': 2,
#  'gbm': 8,
#  'ensemble-learning': 11,
#  'efficiency': 2,
#  'lime': 1,
#  'auc': 3,
#  '.net': 1,
#  'spss': 2,
#  'c++': 1,
#  'anomaly': 3,
#  'counts': 3,
#  'glm': 2,
#  'google-data-studio': 2,
#  'predict': 3,
#  'nl2sql': 1,
#  'sagemaker': 5,
#  'hierarchical-data-format': 6,
#  'gmm': 2,
#  'competitions': 2,
#  'torch': 2,
#  'adaboost': 1,
#  'frequentist': 1,
#  'data-product': 3,
#  'automl': 2,
#  'google-cloud': 2,
#  'multivariate-distribution': 1,
#  'coursera': 3,
#  'hive': 3,
#  'spyder': 1,
#  'sports': 2,
#  'manifold': 1,
#  'experiments': 2,
#  'finite-precision': 2,
#  'active-learning': 3,
#  'automation': 3,
#  'data-stream-mining': 3,
#  'redshift': 1,
#  'gru': 1,
#  'text-classification': 1,
#  'tesseract': 2,
#  'openai-gpt': 2,
#  'causalimpact': 2,
#  '3d-object-detection': 1,
#  'mongodb': 1,
#  'encoder': 1,
#  'categories': 1,
#  'multi-instance-learning': 2,
#  'structured-data': 4,
#  'data-indexing-techniques': 1,
#  'c': 3,
#  'activity-recognition': 2,
#  'density-estimation': 2,
#  'aws-lambda': 1,
#  'open-source': 1,
#  'history': 1,
#  'isolation-forest': 1,
#  'unseen-data': 1,
#  'consumerweb': 1,
#  'hashingvectorizer': 1,
#  'naive-bayes-algorithim': 1,
#  'normal-equation': 1,
#  'domain-adaptation': 1,
#  'theano': 2,
#  'shap': 1,
#  'hog': 1,
#  'esl': 1}

# %% [markdown]
# Transforming the `used_tags` into a dataframe

# %%
#orient{‘columns’, ‘index’}, default ‘columns’
used_tags_df = pd.DataFrame.from_dict(used_tags, orient = 'index')
used_tags_df
# Out:
#                            0
# machine-learning        2332
# neural-network           913
# reinforcement-learning   170
# dqn                       30
# classifier                17
# ...                      ...
# domain-adaptation          1
# theano                     2
# shap                       1
# hog                        1
# esl                        1
#
# [501 rows x 1 columns]

# %%
used_tags_df = used_tags_df.rename({0:'count'}, axis = 1)
used_tags_df
# Out:
#                         count
# machine-learning         2332
# neural-network            913
# reinforcement-learning    170
# dqn                        30
# classifier                 17
# ...                       ...
# domain-adaptation           1
# theano                      2
# shap                        1
# hog                         1
# esl                         1
#
# [501 rows x 1 columns]

# %% [markdown]
# Sorting the `used_tags_df` to get the top 20

# %%
most_used = used_tags_df.sort_values('count').tail(20)
most_used
# Out:
#                         count
# machine-learning-model    195
# statistics                199
# r                         227
# predictive-modeling       230
# clustering                243
# dataset                   284
# regression                303
# lstm                      313
# pandas                    333
# time-series               367
# cnn                       411
# nlp                       434
# tensorflow                480
# scikit-learn              482
# classification            612
# keras                     796
# neural-network            913
# deep-learning            1003
# python                   1580
# machine-learning         2332

# %% [markdown]
# Visualising the above data:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
most_used.plot(kind = 'barh', figsize = (16,8))
# Out:
# <AxesSubplot:>

# %%
questions
# Out:
#          Id  PostTypeId        CreationDate  Score  ViewCount  \
# 0     61536           1 2019-10-10 05:58:58      1        131
# 1     61540           1 2019-10-10 06:51:08      0         26
# 2     61544           1 2019-10-10 08:28:22      0         26
# 3     61546           1 2019-10-10 09:06:55      0        268
# 4     61547           1 2019-10-10 09:37:34      0         15
# ...     ...         ...                 ...    ...        ...
# 7535  52947           1 2019-05-31 00:01:55      2         69
# 7536  52948           1 2019-05-31 00:06:04      1         41
# 7537  52949           1 2019-05-31 00:50:57      1         22
# 7538  52952           1 2019-05-31 03:13:43      1         38
# 7539  52953           1 2019-05-31 04:49:37      1         46
#
#                                                    Tags  AnswerCount  \
# 0     [machine-learning, neural-network, reinforceme...            1
# 1                        [machine-learning, classifier]            1
# 2                                         [dataset, ml]            1
# 3     [machine-learning, python, deep-learning, kera...            1
# 4                                            [r, image]            0
# ...                                                 ...          ...
# 7535       [text-mining, orange, information-retrieval]            0
# 7536  [python, neural-network, cross-validation, dro...            0
# 7537     [prediction, multilabel-classification, score]            0
# 7538  [multiclass-classification, class-imbalance, s...            0
# 7539  [logistic-regression, dimensionality-reduction...            0
#
#       FavoriteCount
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 7535              0
# 7536              0
# 7537              0
# 7538              0
# 7539              0
#
# [7540 rows x 8 columns]

# %% [markdown]
# Next, count how many times each tag was viewed using `pandas.DataFrame.iterrows` to iterate over DataFrame rows as (index, Series) pairs.

# %%
viewed_tags = {}

for key, value in questions.iterrows():
    for tag in value['Tags']:
        if tag in viewed_tags:
            viewed_tags[tag] += value['ViewCount']
        else:
            viewed_tags[tag] = value['ViewCount']
viewed_tags
# Out:
# {'machine-learning': 884100,
#  'neural-network': 431746,
#  'reinforcement-learning': 38666,
#  'dqn': 8411,
#  'classifier': 11001,
#  'dataset': 94029,
#  'ml': 2572,
#  'python': 1373220,
#  'deep-learning': 513770,
#  'keras': 614273,
#  'convnet': 34546,
#  'r': 78015,
#  'image': 13016,
#  'scikit-learn': 321732,
#  'pandas': 617408,
#  'linear-regression': 45824,
#  'classification': 241766,
#  'class-imbalance': 41253,
#  'imbalanced-learn': 8258,
#  'tensorflow': 296186,
#  'data-science-model': 53446,
#  'nlp': 176212,
#  'named-entity-recognition': 8676,
#  'spacy': 10238,
#  'predictive-modeling': 32012,
#  'lstm': 162117,
#  'embeddings': 9494,
#  'data-mining': 84451,
#  'correlation': 28452,
#  'association-rules': 894,
#  'pattern-recognition': 86,
#  'dataframe': 238046,
#  'pca': 14813,
#  'descriptive-statistics': 3040,
#  'normalization': 39452,
#  'ensemble-modeling': 2840,
#  'activation-function': 32135,
#  'gan': 30913,
#  'generative-models': 7609,
#  'mnist': 7767,
#  'sampling': 10573,
#  'time-series': 148104,
#  'regression': 106824,
#  'probability': 12397,
#  'bayesian': 4819,
#  'dirichlet': 596,
#  'object-detection': 27739,
#  'object-recognition': 4421,
#  'statistics': 36276,
#  'cross-validation': 45830,
#  'feature-selection': 64498,
#  'word2vec': 39375,
#  'word-embeddings': 45043,
#  'gensim': 18918,
#  'sequence-to-sequence': 21905,
#  'churn': 1703,
#  'cnn': 173831,
#  'logistic-regression': 46522,
#  'image-classification': 77219,
#  'matplotlib': 67963,
#  'openai-gym': 6235,
#  'hyperparameter': 7591,
#  'hyperparameter-tuning': 17051,
#  'sas': 675,
#  'svm': 28808,
#  'evaluation': 17907,
#  'overfitting': 37338,
#  'k-nn': 11310,
#  'bayes-error': 655,
#  'pytorch': 100230,
#  'meta-learning': 438,
#  'data-cleaning': 69427,
#  'preprocessing': 43590,
#  'missing-data': 27818,
#  'data-analysis': 32950,
#  'data-imputation': 7780,
#  'pooling': 257,
#  'categorical-data': 30574,
#  'encoding': 41921,
#  'convolution': 35919,
#  'cosine-distance': 13298,
#  'rnn': 42982,
#  'text': 7546,
#  'binary': 18583,
#  'model-selection': 8213,
#  'topic-model': 5703,
#  'lda': 7360,
#  'sql': 8856,
#  'seaborn': 85224,
#  'random-forest': 41053,
#  'matlab': 9865,
#  'lda-classifier': 117,
#  'q-learning': 6290,
#  'deep-network': 7622,
#  'bigdata': 28928,
#  'machine-learning-model': 51479,
#  'data': 44794,
#  'kaggle': 30445,
#  'visualization': 43535,
#  'ipython': 13526,
#  '3d-reconstruction': 1932,
#  'transfer-learning': 25874,
#  'faster-rcnn': 6353,
#  'difference': 16104,
#  'grid-search': 12598,
#  'clustering': 76842,
#  'dimensionality-reduction': 13732,
#  'optimization': 27873,
#  'outlier': 25066,
#  'recommender-system': 18870,
#  'gradient-descent': 34492,
#  'knime': 40,
#  'linear-algebra': 6603,
#  'confusion-matrix': 17768,
#  'multilabel-classification': 23911,
#  'clusters': 784,
#  'estimators': 150,
#  'sentiment-analysis': 6960,
#  'labels': 6187,
#  'vgg16': 7225,
#  'numpy': 131470,
#  'apache-spark': 13949,
#  'feature-engineering': 33440,
#  'learning': 1226,
#  'learning-to-rank': 1957,
#  'dynamic-programming': 1478,
#  'multiclass-classification': 45280,
#  'naive-bayes-classifier': 11012,
#  'image-preprocessing': 20358,
#  'mlp': 9802,
#  'perceptron': 5198,
#  'machine-translation': 6898,
#  'natural-language-process': 23913,
#  'k-means': 38876,
#  'accuracy': 36315,
#  'markov-process': 605,
#  'anomaly-detection': 21840,
#  'autoencoder': 34754,
#  'pyspark': 15790,
#  'distribution': 9864,
#  'variance': 9345,
#  'gaussian': 5328,
#  'neural-style-transfer': 396,
#  'policy-gradients': 3522,
#  'ai': 7410,
#  'decision-trees': 52847,
#  'boosting': 15736,
#  'computer-vision': 72190,
#  'self-driving': 106,
#  'stemming': 864,
#  'xgboost': 83973,
#  'unbalanced-classes': 14202,
#  'image-recognition': 16985,
#  'ocr': 5360,
#  'scoring': 5791,
#  'gridsearchcv': 18115,
#  'text-mining': 24370,
#  'information-retrieval': 5390,
#  'bias': 6994,
#  'backpropagation': 27099,
#  'chatbot': 1880,
#  'usecase': 24,
#  'feature-scaling': 16770,
#  'supervised-learning': 16289,
#  'regex': 1320,
#  'sparsity': 82,
#  'explainable-ai': 1524,
#  'feature-extraction': 25666,
#  'orange': 7327,
#  'orange3': 1842,
#  'csv': 102750,
#  'julia': 365,
#  'data-augmentation': 8211,
#  'text-generation': 3945,
#  'text-filter': 19,
#  'training': 43364,
#  'forecasting': 16215,
#  'similar-documents': 9801,
#  'vector-space-models': 2962,
#  'regularization': 12978,
#  'tsne': 2324,
#  'loss-function': 50442,
#  'aws': 3299,
#  'opencv': 54958,
#  'prediction': 37637,
#  'feature-construction': 4876,
#  'data-wrangling': 12304,
#  'javascript': 1103,
#  'geospatial': 3705,
#  'plotting': 5611,
#  'forecast': 23524,
#  'graphical-model': 441,
#  'historgram': 9767,
#  'social-network-analysis': 530,
#  'unsupervised-learning': 24167,
#  'weka': 2321,
#  'bert': 82009,
#  'similarity': 28339,
#  'language-model': 5734,
#  'transformer': 38892,
#  'recurrent-neural-net': 26037,
#  'metadata': 346,
#  'tools': 2682,
#  'yolo': 6920,
#  'sensors': 96,
#  'smote': 13526,
#  'beginner': 3907,
#  'programming': 2366,
#  'algorithms': 10749,
#  'distance': 11108,
#  'lightgbm': 18406,
#  'performance': 4615,
#  'features': 4292,
#  'dropout': 14038,
#  'tfidf': 8741,
#  'batch-normalization': 12039,
#  'databases': 6814,
#  'project-planning': 296,
#  'audio-recognition': 4780,
#  'research': 806,
#  'vae': 9543,
#  'neural': 10335,
#  'google': 9439,
#  'excel': 41429,
#  'kernel': 4717,
#  'mathematics': 14967,
#  'multi-output': 1892,
#  'functional-api': 232,
#  'relational-dbms': 127,
#  'noise': 2931,
#  'online-learning': 2295,
#  'h2o': 848,
#  'graphs': 12188,
#  'notation': 420,
#  'terminology': 3651,
#  'nltk': 16904,
#  'stanford-nlp': 3304,
#  'indexing': 9168,
#  'corpus': 34,
#  'wikipedia': 34,
#  'matrix': 7140,
#  'twitter': 283,
#  'actor-critic': 3415,
#  'keras-rl': 2413,
#  'annotation': 1684,
#  'fuzzy-logic': 1815,
#  'fuzzy-classification': 479,
#  'ab-test': 159,
#  'weight-initialization': 447,
#  'jupyter': 27346,
#  'pickle': 4672,
#  'mean-shift': 243,
#  'siamese-networks': 235,
#  'semantic-similarity': 298,
#  'simulation': 1677,
#  'data-formats': 72259,
#  'mse': 266,
#  'genetic-algorithms': 1331,
#  'community': 51,
#  'rbm': 117,
#  'error-handling': 3604,
#  'monte-carlo': 8097,
#  'collinearity': 2094,
#  'anonymization': 1439,
#  'scipy': 16604,
#  'arima': 5055,
#  'python-3.x': 3120,
#  'statsmodels': 10,
#  'json': 13530,
#  'lasso': 518,
#  'rstudio': 2676,
#  'ggplot2': 242,
#  'software-development': 1098,
#  'hardware': 2223,
#  'metric': 23877,
#  'web-scraping': 420,
#  'math': 4172,
#  'matrix-factorisation': 1157,
#  'methodology': 465,
#  'gpu': 57794,
#  'softmax': 10094,
#  'homework': 413,
#  'theory': 469,
#  'evolutionary-algorithms': 830,
#  'reference-request': 2209,
#  'semi-supervised-learning': 1458,
#  'scraping': 437,
#  'java': 895,
#  'sequence': 7143,
#  'dummy-variables': 10135,
#  'self-study': 1655,
#  'code': 434,
#  'gaussian-process': 938,
#  'cost-function': 23837,
#  'colab': 18057,
#  'data-leakage': 1853,
#  'sequential-pattern-mining': 632,
#  'mini-batch-gradient-descent': 1156,
#  'sap': 27,
#  'attention-mechanism': 41268,
#  'aggregation': 1561,
#  'implementation': 8001,
#  'privacy': 1149,
#  'anaconda': 25565,
#  'galago': 15,
#  'caffe': 79,
#  'learning-rate': 6101,
#  'pipelines': 5494,
#  'methods': 10612,
#  'ranking': 1476,
#  'score': 3845,
#  'nosql': 67,
#  'reshape': 1418,
#  'etl': 1307,
#  'weighted-data': 6064,
#  'google-prediction-api': 36,
#  'market-basket-analysis': 1078,
#  'non-parametric': 385,
#  'bayesian-nonparametric': 54,
#  'survival-analysis': 3767,
#  'discriminant-analysis': 1013,
#  'time': 9874,
#  'nlg': 1766,
#  'powerbi': 2203,
#  'management': 91,
#  'generalization': 636,
#  'word': 234,
#  'representation': 560,
#  'career': 1951,
#  'data.table': 27938,
#  'scala': 2040,
#  'least-squares-svm': 313,
#  'markov': 188,
#  'windows': 2782,
#  'multitask-learning': 2376,
#  'inception': 2098,
#  'probability-calibration': 3033,
#  'finetuning': 746,
#  'automatic-summarization': 1236,
#  'serialisation': 3502,
#  'bayesian-networks': 1502,
#  'rbf': 1020,
#  'finance': 4122,
#  'parameter-estimation': 1130,
#  'ensemble': 689,
#  'numerical': 1614,
#  'hinge-loss': 1127,
#  'one-shot-learning': 713,
#  'octave': 293,
#  'search-engine': 271,
#  'question-answering': 391,
#  'huggingface': 284,
#  'ndcg': 1817,
#  'discounted-reward': 899,
#  'parallel': 1344,
#  'parsing': 347,
#  'tokenization': 2584,
#  'derivation': 136,
#  'inceptionresnetv2': 1529,
#  'markov-hidden-model': 720,
#  'bioinformatics': 287,
#  'search': 248,
#  'mcmc': 93,
#  'feature-reduction': 2065,
#  'marketing': 805,
#  'distributed': 294,
#  'svr': 1227,
#  'smotenc': 2745,
#  'books': 1563,
#  'predictor-importance': 1909,
#  'feature-map': 82,
#  'dbscan': 10852,
#  'expectation-maximization': 266,
#  'cloud-computing': 698,
#  'epochs': 25040,
#  'software-recommendation': 1868,
#  'deepmind': 1622,
#  'vc-theory': 1041,
#  'crawling': 78,
#  'movielens': 2027,
#  'image-size': 299,
#  'infographics': 128,
#  'stata': 65,
#  'wolfram-language': 436,
#  'azure-ml': 1021,
#  'convergence': 2463,
#  'processing': 575,
#  'momentum': 21,
#  'stacked-lstm': 578,
#  'apache-hadoop': 1142,
#  'scalability': 2232,
#  'information-theory': 428,
#  'mutual-information': 404,
#  'doc2vec': 159,
#  'nvidia': 6824,
#  'game': 424,
#  'state-of-the-art': 17,
#  'ann': 106,
#  'randomized-algorithms': 4788,
#  'jaccard-coefficient': 1290,
#  'rmse': 122,
#  'interpolation': 1331,
#  'anova': 276,
#  'dplyr': 4735,
#  'image-segmentation': 244,
#  'tableau': 444,
#  'heatmap': 1128,
#  'genetic-programming': 243,
#  'parameter': 1449,
#  'map-reduce': 243,
#  'ngrams': 154,
#  'education': 80,
#  'manhattan': 429,
#  'version-control': 174,
#  'pruning': 573,
#  'networkx': 1313,
#  'probabilistic-programming': 1172,
#  'alex-net': 274,
#  'pytorch-geometric': 1049,
#  'allennlp': 457,
#  'interpretation': 516,
#  'pip': 839,
#  'pac-learning': 776,
#  'linux': 4508,
#  'objective-function': 53,
#  'definitions': 759,
#  'ridge-regression': 1821,
#  'fastai': 469,
#  'cloud': 632,
#  'categorical-encoding': 357,
#  'speech-to-text': 457,
#  'one-hot-encoding': 279,
#  'pearsons-correlation-coefficient': 8289,
#  'spearmans-rank-correlation': 7974,
#  'kendalls-tau-coefficient': 7974,
#  'groupby': 145,
#  'gbm': 2293,
#  'ensemble-learning': 1341,
#  'efficiency': 53,
#  'lime': 381,
#  'auc': 143,
#  '.net': 585,
#  'spss': 351,
#  'c++': 156,
#  'anomaly': 327,
#  'counts': 153,
#  'glm': 315,
#  'google-data-studio': 104,
#  'predict': 709,
#  'nl2sql': 22,
#  'sagemaker': 926,
#  'hierarchical-data-format': 489,
#  'gmm': 95,
#  'competitions': 176,
#  'torch': 70,
#  'adaboost': 38,
#  'frequentist': 16,
#  'data-product': 1630,
#  'automl': 145,
#  'google-cloud': 182,
#  'multivariate-distribution': 8,
#  'coursera': 421,
#  'hive': 111,
#  'spyder': 1205,
#  'sports': 51,
#  'manifold': 124,
#  'experiments': 55,
#  'finite-precision': 74,
#  'active-learning': 219,
#  'automation': 159,
#  'data-stream-mining': 1041,
#  'redshift': 30,
#  'gru': 22,
#  'text-classification': 45,
#  'tesseract': 1220,
#  'openai-gpt': 230,
#  'causalimpact': 175,
#  '3d-object-detection': 51,
#  'mongodb': 103,
#  'encoder': 69,
#  'categories': 36,
#  'multi-instance-learning': 108,
#  'structured-data': 478,
#  'data-indexing-techniques': 302,
#  'c': 273,
#  'activity-recognition': 87,
#  'density-estimation': 1704,
#  'aws-lambda': 1951,
#  'open-source': 28,
#  'history': 23,
#  'isolation-forest': 94,
#  'unseen-data': 82,
#  'consumerweb': 26,
#  'hashingvectorizer': 262,
#  'naive-bayes-algorithim': 262,
#  'normal-equation': 2103,
#  'domain-adaptation': 133,
#  'theano': 186,
#  'shap': 328,
#  'hog': 24,
#  'esl': 739}

# %%
viewed_tags_df = pd.DataFrame.from_dict(viewed_tags, orient = 'index')

# %%
viewed_tags_df = viewed_tags_df.rename({0:'views'}, axis = 1)
viewed_tags_df.head()
# Out:
#                          views
# machine-learning        884100
# neural-network          431746
# reinforcement-learning   38666
# dqn                       8411
# classifier               11001

# %% [markdown]
# Sorting the `viewed_tags_df` to get the top 20

# %%
most_viewed = viewed_tags_df.sort_values('views').tail(20)
most_viewed
# Out:
#                     views
# seaborn             85224
# dataset             94029
# pytorch            100230
# csv                102750
# regression         106824
# numpy              131470
# time-series        148104
# lstm               162117
# cnn                173831
# nlp                176212
# dataframe          238046
# classification     241766
# tensorflow         296186
# scikit-learn       321732
# neural-network     431746
# deep-learning      513770
# keras              614273
# pandas             617408
# machine-learning   884100
# python            1373220

# %% [markdown]
# Visualising the above

# %%
most_viewed.plot(kind = 'barh', figsize = (16,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Ploting `most_used` and `most_viewed` side by side

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
fig.set_size_inches((24, 10))
most_used.plot(kind="barh", ax=axes[0], subplots=True)
most_viewed.plot(kind="barh", ax=axes[1], subplots=True)
# Out:
# array([<AxesSubplot:title={'center':'views'}>], dtype=object)

# %% [markdown]
# ## Relationship Between Tags
#
# `most_used` is a dataframe that counts how many times each of the top 20 tags was used.
# `most_viewed` is a dataframe that counts how many times each of the top 20 tags was viewed.
#
# Looking at the results, we see that most top tags are present in both dataframes.
#
# Let's see what tags are in `most_used`, but not in `most_viewed`. We can identify them by the missing values in ViewCount below.

# %%
in_used = pd.merge(most_used, most_viewed, how="left", left_index=True, right_index=True)
in_used
# Out:
#                         count      views
# machine-learning-model    195        NaN
# statistics                199        NaN
# r                         227        NaN
# predictive-modeling       230        NaN
# clustering                243        NaN
# dataset                   284    94029.0
# regression                303   106824.0
# lstm                      313   162117.0
# pandas                    333   617408.0
# time-series               367   148104.0
# cnn                       411   173831.0
# nlp                       434   176212.0
# tensorflow                480   296186.0
# scikit-learn              482   321732.0
# classification            612   241766.0
# keras                     796   614273.0
# neural-network            913   431746.0
# deep-learning            1003   513770.0
# python                   1580  1373220.0
# machine-learning         2332   884100.0

# %% [markdown]
# Similarly, let's see what tags are in the latter, but not the former:

# %%
pd.merge(most_used, most_viewed, how="right", left_index=True, right_index=True)
# Out:
#                    count    views
# seaborn              NaN    85224
# dataset            284.0    94029
# pytorch              NaN   100230
# csv                  NaN   102750
# regression         303.0   106824
# numpy                NaN   131470
# time-series        367.0   148104
# lstm               313.0   162117
# cnn                411.0   173831
# nlp                434.0   176212
# dataframe            NaN   238046
# classification     612.0   241766
# tensorflow         480.0   296186
# scikit-learn       482.0   321732
# neural-network     913.0   431746
# deep-learning     1003.0   513770
# keras              796.0   614273
# pandas             333.0   617408
# machine-learning  2332.0   884100
# python            1580.0  1373220

# %% [markdown]
# The tags present in `most_used` and not present in `most_viewed` are:
#
# * `machine-learning-model`
# * `statistics`
# * `predictive-modeling`
# * `r`
# * `clustering`
#
# And the tags present in `most_viewed` but not in `most_used` are:
#
# * `csv`
# * `pytorch`
# * `dataframe`
# * `seaborn`
# * `numpy`
#
# Some tags also stand out as being related. For example, `python` is related to `pandas`because pandas is a Python library. Other pairs of tags, shouldn't be related at all, like `pandas` and `r`
#
# **How are these tags related?**
#
# Let's count how many times these tags appear

# %%
#The index (row labels) of the DataFrame.
all_tags = list(viewed_tags_df.index)

# %% [markdown]
# We'll now create a dataframe where each row will represent a tag, and each column as well.

# %%
associations = pd.DataFrame(index=all_tags, columns=all_tags)
associations.iloc[0:4,0:4]
# Out:
#                        machine-learning neural-network reinforcement-learning  \
# machine-learning                    NaN            NaN                    NaN
# neural-network                      NaN            NaN                    NaN
# reinforcement-learning              NaN            NaN                    NaN
# dqn                                 NaN            NaN                    NaN
#
#                         dqn
# machine-learning        NaN
# neural-network          NaN
# reinforcement-learning  NaN
# dqn                     NaN

# %% [markdown]
# We will now fill this dataframe with zeroes and then, for each lists of tags in `questions["Tags"]`, we will increment the intervening tags by one. The end result will be a dataframe that for each pair of tags, it tells us how many times they were used together.

# %%
associations.fillna(0, inplace=True)

for tags in questions["Tags"]:
    associations.loc[tags, tags] += 1

# %%
associations
# Out:
#                         machine-learning  neural-network  \
# machine-learning                    2332             323
# neural-network                       323             913
# reinforcement-learning                37              19
# dqn                                    3               1
# classifier                             5               3
# ...                                  ...             ...
# domain-adaptation                      1               0
# theano                                 0               0
# shap                                   0               0
# hog                                    0               0
# esl                                    0               0
#
#                         reinforcement-learning  dqn  classifier  dataset  ml  \
# machine-learning                            37    3           5       86   1
# neural-network                              19    1           3       17   0
# reinforcement-learning                     170   30           0        1   0
# dqn                                         30   30           0        0   0
# classifier                                   0    0          17        0   0
# ...                                        ...  ...         ...      ...  ..
# domain-adaptation                            0    0           0        0   0
# theano                                       0    0           0        0   0
# shap                                         0    0           0        0   0
# hog                                          0    0           0        0   0
# esl                                          0    0           0        0   0
#
#                         python  deep-learning  keras  ...  unseen-data  \
# machine-learning           443            361    170  ...            0
# neural-network             123            269    211  ...            0
# reinforcement-learning      15             41      7  ...            0
# dqn                          2             10      1  ...            0
# classifier                   4              0      0  ...            0
# ...                        ...            ...    ...  ...          ...
# domain-adaptation            0              0      0  ...            0
# theano                       1              0      1  ...            0
# shap                         0              0      0  ...            0
# hog                          0              0      0  ...            0
# esl                          0              0      0  ...            0
#
#                         consumerweb  hashingvectorizer  \
# machine-learning                  0                  1
# neural-network                    0                  0
# reinforcement-learning            0                  0
# dqn                               0                  0
# classifier                        0                  0
# ...                             ...                ...
# domain-adaptation                 0                  0
# theano                            0                  0
# shap                              0                  0
# hog                               0                  0
# esl                               0                  0
#
#                         naive-bayes-algorithim  normal-equation  \
# machine-learning                             1                1
# neural-network                               0                0
# reinforcement-learning                       0                0
# dqn                                          0                0
# classifier                                   0                0
# ...                                        ...              ...
# domain-adaptation                            0                0
# theano                                       0                0
# shap                                         0                0
# hog                                          0                0
# esl                                          0                0
#
#                         domain-adaptation  theano  shap  hog  esl
# machine-learning                        1       0     0    0    0
# neural-network                          0       0     0    0    0
# reinforcement-learning                  0       0     0    0    0
# dqn                                     0       0     0    0    0
# classifier                              0       0     0    0    0
# ...                                   ...     ...   ...  ...  ...
# domain-adaptation                       1       0     0    0    0
# theano                                  0       2     0    0    0
# shap                                    0       0     1    0    0
# hog                                     0       0     0    1    0
# esl                                     0       0     0    0    1
#
# [501 rows x 501 columns]

# %% [markdown]
# This dataframe is quite large. We'll focus our attention on the most used tags. We'll add some colors to make it easier to talk about the dataframe. Visit this **[site](https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html)** for further explanation on the below.

# %%
relations_most_used = associations.loc[most_used.index, most_used.index]

def style_cells(x):
    helper_df = pd.DataFrame('', index=x.index, columns=x.columns) ###
    helper_df.loc["time-series", "r"] = "background-color: yellow"
    helper_df.loc["r", "time-series"] = "background-color: yellow"
    for k in range(helper_df.shape[0]):
        helper_df.iloc[k,k] = "color: blue"
    
    return helper_df

relations_most_used.style.apply(style_cells, axis=None) #Styler.apply(func, axis=0) for columnwise styles
# Out:
# <style  type="text/css" >
# #T_488c0df8_f359_11ea_8a89_8c85908d5d05row0_col0,#T_488c0df8_f359_11ea_8a89_8c85908d5d05row1_col1,#T_488c0df8_f359_11ea_8a89_8c85908d5d05row2_col2,#T_488c0df8_f359_11ea_8a89_8c85908d5d05row3_col3,#T_488c0df8_f359_11ea_8a89_8c85908d5d05row4_col4,#T_488c0df8_f359_11ea_8a89_8c85908d5d05row5_col5,#T_488c0df8_f359_11ea_8a89_8c85908d5d05row6_col6,#T_488c0df8_f359_11ea_8a89_8c85908d5d05row7_col7,#T_488c0df8_f359_11ea_8a89_8c85908d5d05row8_col8,#T_488c0df8_f359_11ea_8a89_8c85908d5d05row9_col9,#T_488c0df8_f359_11ea_8a89_8c85908d5d05row10_col10,#T_488c0df8_f359_11ea_8a89_8c85908d5d05row11_col11,#T_488c0df8_f359_11ea_8a89_8c85908d5d05row12_col12,#T_488c0df8_f359_11ea_8a89_8c85908d5d05row13_col13,#T_488c0df8_f359_11ea_8a89_8c85908d5d05row14_col14,#T_488c0df8_f359_11ea_8a89_8c85908d5d05row15_col15,#T_488c0df8_f359_11ea_8a89_8c85908d5d05row16_col16,#T_488c0df8_f359_11ea_8a89_8c85908d5d05row17_col17,#T_488c0df8_f359_11ea_8a89_8c85908d5d05row18_col18,#T_488c0df8_f359_11ea_8a89_8c85908d5d05row19_col19{
#             color:  blue;
#         }#T_488c0df8_f359_11ea_8a89_8c85908d5d05row2_col9,#T_488c0df8_f359_11ea_8a89_8c85908d5d05row9_col2{
#             background-color:  yellow;
#         }</style><table id="T_488c0df8_f359_11ea_8a89_8c85908d5d05" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >machine-learning-model</th>        <th class="col_heading level0 col1" >statistics</th>        <th class="col_heading level0 col2" >r</th>        <th class="col_heading level0 col3" >predictive-modeling</th>        <th class="col_heading level0 col4" >clustering</th>        <th class="col_heading level0 col5" >dataset</th>        <th class="col_heading level0 col6" >regression</th>        <th class="col_heading level0 col7" >lstm</th>        <th class="col_heading level0 col8" >pandas</th>        <th class="col_heading level0 col9" >time-series</th>        <th class="col_heading level0 col10" >cnn</th>        <th class="col_heading level0 col11" >nlp</th>        <th class="col_heading level0 col12" >tensorflow</th>        <th class="col_heading level0 col13" >scikit-learn</th>        <th class="col_heading level0 col14" >classification</th>        <th class="col_heading level0 col15" >keras</th>        <th class="col_heading level0 col16" >neural-network</th>        <th class="col_heading level0 col17" >deep-learning</th>        <th class="col_heading level0 col18" >python</th>        <th class="col_heading level0 col19" >machine-learning</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_488c0df8_f359_11ea_8a89_8c85908d5d05level0_row0" class="row_heading level0 row0" >machine-learning-model</th>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row0_col0" class="data row0 col0" >195</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row0_col1" class="data row0 col1" >3</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row0_col2" class="data row0 col2" >6</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row0_col3" class="data row0 col3" >18</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row0_col4" class="data row0 col4" >3</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row0_col5" class="data row0 col5" >11</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row0_col6" class="data row0 col6" >8</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row0_col7" class="data row0 col7" >3</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row0_col8" class="data row0 col8" >3</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row0_col9" class="data row0 col9" >5</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row0_col10" class="data row0 col10" >3</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row0_col11" class="data row0 col11" >4</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row0_col12" class="data row0 col12" >8</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row0_col13" class="data row0 col13" >16</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row0_col14" class="data row0 col14" >21</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row0_col15" class="data row0 col15" >13</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row0_col16" class="data row0 col16" >9</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row0_col17" class="data row0 col17" >16</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row0_col18" class="data row0 col18" >34</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row0_col19" class="data row0 col19" >121</td>
#             </tr>
#             <tr>
#                         <th id="T_488c0df8_f359_11ea_8a89_8c85908d5d05level0_row1" class="row_heading level0 row1" >statistics</th>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row1_col0" class="data row1 col0" >3</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row1_col1" class="data row1 col1" >199</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row1_col2" class="data row1 col2" >10</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row1_col3" class="data row1 col3" >14</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row1_col4" class="data row1 col4" >3</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row1_col5" class="data row1 col5" >13</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row1_col6" class="data row1 col6" >14</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row1_col7" class="data row1 col7" >1</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row1_col8" class="data row1 col8" >2</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row1_col9" class="data row1 col9" >16</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row1_col10" class="data row1 col10" >1</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row1_col11" class="data row1 col11" >3</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row1_col12" class="data row1 col12" >0</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row1_col13" class="data row1 col13" >4</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row1_col14" class="data row1 col14" >16</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row1_col15" class="data row1 col15" >1</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row1_col16" class="data row1 col16" >10</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row1_col17" class="data row1 col17" >11</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row1_col18" class="data row1 col18" >31</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row1_col19" class="data row1 col19" >81</td>
#             </tr>
#             <tr>
#                         <th id="T_488c0df8_f359_11ea_8a89_8c85908d5d05level0_row2" class="row_heading level0 row2" >r</th>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row2_col0" class="data row2 col0" >6</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row2_col1" class="data row2 col1" >10</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row2_col2" class="data row2 col2" >227</td>
#                         <td id="T_488c0df8_f359_11ea_8a89_8c85908d5d05row2

# %% [markdown]
# The cells highlighted in yellow tell us that `time-series` was used together with `r` **18** times. The values in blue tell us how many times each of the tags was used. We saw earlier that machine-learning was used **2332** times and we confirm it in this dataframe (at the very bottom right).
# It's hard for a human to understand what is going on in this dataframe.
#
# Let's create a heatmap. But before we do it, let's get rid of the values in blue, otherwise the colors will be too skewed.

# %%
for i in range(relations_most_used.shape[0]):
    relations_most_used.iloc[i,i] = pd.np.NaN ###
# Out:
# <ipython-input-31-f79b05a355d3>:2: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   relations_most_used.iloc[i,i] = pd.np.NaN ###

# %%
import seaborn as sns
plt.figure(figsize=(12,8))
#annot: If True, write the data value in each cell
sns.heatmap(relations_most_used, cmap="Greens", annot=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The most used tags also seem to have the strongest relationships, as given by the dark concentration in the bottom right corner. However, this could simply be because each of these tags is used a lot, and so end up being used together a lot without possibly even having any strong relation between them.
#
# A more intuitive manifestation of this phenomenon is the following. A lot of people buy bread, a lot of people buy toilet paper, so they end up being purchased together a lot, but purchasing one of them doesn't increase the chances of purchasing the other.
#
# Another shortcoming of this attempt is that it only looks at relations between pairs of tags and not between multiple groups of tags. For example, it could be the case that when used together, `dataset` and `scikit-learn ` have a "strong" relation to `pandas`, but each by itself doesn't.

# %% [markdown]
# ## Enter Domain Knowledge
#
# Although analytical solutions to the problem set above exist, they aren't necessarily needed, nor the best way to go about solving the problem.
#
# [Domain knowledge](https://en.wikipedia.org/wiki/Domain_knowledge) can be very useful. Most used tags are also the most viewed. From the top 10 tags of each, here's a list of the tags in common: `python`, `machine-learning`, `deep-learning`, `neural-network`, `keras`, `tensorflow`, `classification`, `scikit-learn`.
#
# [Keras](https://keras.io/), [scikit-learn](https://scikit-learn.org/), [TensorFlow](https://www.tensorflow.org/) are all Python libraries that allow their users to employ deep learning (a type of neural network).
# Most of the top tags are all intimately related with one central machine learning theme: deep learning.
#
# At the glance of an eye, the most popular topic at the moment, as shown by our analysis, is `deep learning`.

# %% [markdown]
# ## Just the Fad?
#
# Before we officially make our recommendation, one thing that comes to mind is "Is deep learning just a fad?" Ideally, the content we decide to create will be the most useful for as long as possible. Could interest in deep learning be going down?
#
# In this we will track the interest in deep learning across time:
#
# * Count how many deep learning questions are asked per time period.
# * The total amount of questions per time period.
# * How many deep learning questions there are relative to the total amount of questions per time period.
#
# The file `all_questions.csv` holds the result of the query below — this query fetches all of the questions ever asked on DSSE, their dates and tags.
#
# ![Screen%20Shot%202020-09-09%20at%2014.06.43.png](attachment:Screen%20Shot%202020-09-09%20at%2014.06.43.png)
#
# Let's read in the file into a dataframe called `all_q`. We'll parse the dates at read-time.

# %%
all_questions = pd.read_csv('all_questions.csv', parse_dates=['CreationDate'])
all_q = all_questions.copy()

# %% [markdown]
# Transform the tags column in a similar manner to what was previously done.

# %%
all_q["Tags"] = all_q["Tags"].str.replace("^<|>$", "").str.split("><")

# %%
all_q
# Out:
#           Id        CreationDate  \
# 0      42585 2018-12-14 03:50:39
# 1      42587 2018-12-14 05:11:46
# 2      42589 2018-12-14 05:25:59
# 3      42591 2018-12-14 07:23:14
# 4      42599 2018-12-14 09:08:14
# ...      ...                 ...
# 25780  81282 2020-09-05 15:33:40
# 25781  81283 2020-09-05 16:15:17
# 25782  81284 2020-09-05 16:32:50
# 25783  81285 2020-09-05 17:40:56
# 25784  81286 2020-09-05 18:39:30
#
#                                                     Tags
# 0                                  [neural-network, gpu]
# 1                                    [scikit-learn, svm]
# 2                     [machine-learning, classification]
# 3                        [clustering, similarity, tfidf]
# 4      [neural-network, deep-learning, keras, tensorf...
# ...                                                  ...
# 25780  [neural-network, loss-function, siamese-networks]
# 25781  [machine-learning, python, q-learning, impleme...
# 25782                           [bigdata, data-analysis]
# 25783  [scikit-learn, time-series, clustering, k-nn, ...
# 25784                        [predictive-modeling, time]
#
# [25785 rows x 3 columns]

# %% [markdown]
# Before deciding which questions should be classified as being deep learning questions, we should decide what tags are deep learning tags.
#
# The definition of what constitutes a deep learning tag we'll use is: a tag that belongs to the list `["lstm", "cnn", "scikit-learn", "tensorflow", "keras", "neural-network", "deep-learning"]`.
#
# This list was obtained by looking at all the tags in `most_used` and seeing which ones had any relation to deep learning and using Google.
#
# We'll now create a function that assigns `1` to deep learning questions and `0` otherwise; and we use it.

# %%
def class_deep_learning(tags):
    for tag in tags:
        if tag in ["lstm", "cnn", "scikit-learn", "tensorflow", "keras", 
                   "neural-network", "deep-learning"]:
            return 1
        else:
            return 0

# %%
all_q['deep_learning'] = all_q['Tags'].apply(class_deep_learning)

# %%
all_q.sample(5)
# Out:
#           Id        CreationDate  \
# 1445   62086 2019-10-22 15:35:49
# 25020  79627 2020-08-01 11:48:35
# 23431  77460 2020-07-10 01:07:44
# 2588   24363 2017-11-04 20:37:03
# 2586   24351 2017-11-04 12:56:01
#
#                                                     Tags  deep_learning
# 1445   [python, deep-learning, keras, lstm, multilabe...              0
# 25020                                 [machine-learning]              0
# 23431                   [python, clustering, matplotlib]              0
# 2588   [machine-learning, python, scikit-learn, prepr...              0
# 2586            [machine-learning, statistics, homework]              0

# %% [markdown]
# Since we don't have all the data for the first quarter of 2020, we'll get rid of those dates:

# %%
all_q = all_q[all_q["CreationDate"].dt.year < 2020]
all_q
# Out:
#           Id        CreationDate  \
# 0      42585 2018-12-14 03:50:39
# 1      42587 2018-12-14 05:11:46
# 2      42589 2018-12-14 05:25:59
# 3      42591 2018-12-14 07:23:14
# 4      42599 2018-12-14 09:08:14
# ...      ...                 ...
# 25001  13450 2016-08-16 09:16:24
# 25002  13455 2016-08-16 12:18:44
# 25003  13461 2016-08-16 14:38:24
# 25004  13465 2016-08-16 15:38:29
# 25005  13469 2016-08-16 18:09:00
#
#                                                     Tags  deep_learning
# 0                                  [neural-network, gpu]              1
# 1                                    [scikit-learn, svm]              1
# 2                     [machine-learning, classification]              0
# 3                        [clustering, similarity, tfidf]              0
# 4      [neural-network, deep-learning, keras, tensorf...              1
# ...                                                  ...            ...
# 25001                    [dataset, image-classification]              0
# 25002            [machine-learning, graphs, distributed]              0
# 25003                            [neural-network, keras]              1
# 25004  [python, scikit-learn, decision-trees, error-h...              0
# 25005                                   [neural-network]              1
#
# [19789 rows x 4 columns]

# %% [markdown]
# Let's track it quarterly - let's create a column that identifies the quarter in which a question was asked.

# %%
def fetch_quarter(datetime):
    year = str(datetime.year)[-2:]
    quarter = str(((datetime.month-1) // 3) + 1)
    return "{y}Q{q}".format(y=year, q=quarter)

all_q["Quarter"] = all_q["CreationDate"].apply(fetch_quarter)
# Out:
# <ipython-input-40-3f124a9da629>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_q["Quarter"] = all_q["CreationDate"].apply(fetch_quarter)

# %%
all_q.head()
# Out:
#       Id        CreationDate  \
# 0  42585 2018-12-14 03:50:39
# 1  42587 2018-12-14 05:11:46
# 2  42589 2018-12-14 05:25:59
# 3  42591 2018-12-14 07:23:14
# 4  42599 2018-12-14 09:08:14
#
#                                                 Tags  deep_learning Quarter
# 0                              [neural-network, gpu]              1    18Q4
# 1                                [scikit-learn, svm]              1    18Q4
# 2                 [machine-learning, classification]              0    18Q4
# 3                    [clustering, similarity, tfidf]              0    18Q4
# 4  [neural-network, deep-learning, keras, tensorf...              1    18Q4

# %% [markdown]
# The last steps:
#
# * Count how many deep learning questions are asked per time period.
# * The total amount of questions per time period.
# * How many deep learning questions there are relative to the total amount of questions per time period;

# %%
quarterly = all_q.groupby('Quarter').agg({"deep_learning": ['sum', 'size']})
quarterly
# Out:
#         deep_learning
#                   sum  size
# Quarter
# 14Q2                3   157
# 14Q3                4   188
# 14Q4                4   214
# 15Q1                5   190
# 15Q2                6   284
# 15Q3               13   311
# 15Q4               19   382
# 16Q1               38   515
# 16Q2               45   517
# 16Q3               70   584
# 16Q4               76   527
# 17Q1              105   696
# 17Q2              105   645
# 17Q3              115   712
# 17Q4              145   895
# 18Q1              214  1218
# 18Q2              259  1441
# 18Q3              322  1483
# 18Q4              260  1290
# 19Q1              366  1761
# 19Q2              364  1830
# 19Q3              398  1939
# 19Q4              411  2010

# %%
# rename the columns
quarterly.columns = ['DeepLearningQuestions', 'TotalQuestions']
quarterly
# Out:
#          DeepLearningQuestions  TotalQuestions
# Quarter
# 14Q2                         3             157
# 14Q3                         4             188
# 14Q4                         4             214
# 15Q1                         5             190
# 15Q2                         6             284
# 15Q3                        13             311
# 15Q4                        19             382
# 16Q1                        38             515
# 16Q2                        45             517
# 16Q3                        70             584
# 16Q4                        76             527
# 17Q1                       105             696
# 17Q2                       105             645
# 17Q3                       115             712
# 17Q4                       145             895
# 18Q1                       214            1218
# 18Q2                       259            1441
# 18Q3                       322            1483
# 18Q4                       260            1290
# 19Q1                       366            1761
# 19Q2                       364            1830
# 19Q3                       398            1939
# 19Q4                       411            2010

# %%
quarterly['deep_learning_rate'] = quarterly['DeepLearningQuestions']/quarterly['TotalQuestions']

# %%
quarterly.reset_index(inplace=True)
quarterly
# Out:
#    Quarter  DeepLearningQuestions  TotalQuestions  deep_learning_rate
# 0     14Q2                      3             157            0.019108
# 1     14Q3                      4             188            0.021277
# 2     14Q4                      4             214            0.018692
# 3     15Q1                      5             190            0.026316
# 4     15Q2                      6             284            0.021127
# 5     15Q3                     13             311            0.041801
# 6     15Q4                     19             382            0.049738
# 7     16Q1                     38             515            0.073786
# 8     16Q2                     45             517            0.087041
# 9     16Q3                     70             584            0.119863
# 10    16Q4                     76             527            0.144213
# 11    17Q1                    105             696            0.150862
# 12    17Q2                    105             645            0.162791
# 13    17Q3                    115             712            0.161517
# 14    17Q4                    145             895            0.162011
# 15    18Q1                    214            1218            0.175698
# 16    18Q2                    259            1441            0.179736
# 17    18Q3                    322            1483            0.217127
# 18    18Q4                    260            1290            0.201550
# 19    19Q1                    366            1761            0.207836
# 20    19Q2                    364            1830            0.198907
# 21    19Q3                    398            1939            0.205260
# 22    19Q4                    411            2010            0.204478

# %% [markdown]
# Plotting our data

# %%
ax1 = quarterly.plot(x="Quarter", y="deep_learning_rate",
                    kind="line", linestyle="-", marker="8", color="orange",
                    figsize=(24,12)
                    )

ax2 = quarterly.plot(x="Quarter", y="TotalQuestions",
                     kind="bar", ax=ax1, secondary_y=True, alpha=0.7, rot=45) #soften colour by adjusting 'alpha'
# Out:
# /usr/local/Cellar/jupyterlab/2.2.6/libexec/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %% [markdown]
# From the data visualisation above, it is clear that deep learning quetsions has been increasing since the 2014 and has plateaued/plateauing. No evidence to suggest decreasing in these questions. Therefore, **my recommendation will be to create deep learning content**.
